# %%
place = 'los angeles'
keyword = 'android developer'

# %%
def get_job_list(place: str, keyword: str) -> list:
    import requests
    from bs4 import BeautifulSoup
    
    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, sdch, br',
        'accept-language': 'en-GB,en-US;q=0.8,en;q=0.6',
        'referer': 'https://www.glassdoor.com/',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/51.0.2704.79 Chrome/51.0.2704.79 Safari/537.36',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive'
    }
    
    location_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.01',
        'accept-encoding': 'gzip, deflate, sdch, br',
        'accept-language': 'en-GB,en-US;q=0.8,en;q=0.6',
        'referer': 'https://www.glassdoor.com/',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/51.0.2704.79 Chrome/51.0.2704.79 Safari/537.36',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive'
    }

    data = {"term": place,
            "maxLocationsToReturn": 10}
    
    location_url = "https://www.glassdoor.co.in/findPopularLocationAjax.htm?"
    
    try:
        # get location id for search location
        location_response = requests.post(location_url, headers=location_headers, data=data).json()
        place_id = location_response[0]['locationId']
        job_list_url = 'https://www.glassdoor.com/Job/jobs.htm'
        absolute_url = 'https://www.glassdoor.com'
        data = {
            'clickSource': 'searchBtn',
            'sc.keyword': keyword,
            'locT': 'C',
            'locId': place_id,
            'jobType': ''
        }
        
        result_list = list()
        
        if place_id:
            response = requests.post(job_list_url, headers=headers, data=data)
            results_page = BeautifulSoup(response.content,'lxml')
            jobs = results_page.find('', class_='jlGrid hover').find_all('li')
            for job in jobs:
                # get the attributes of the job
                job_name = job.find('div', class_='flexbox jobTitle').find('a').get_text()
                job_url = absolute_url+job.find('div', class_='flexbox jobTitle').find('a').get('href')
                company_location = job.find('div', class_='flexbox empLoc').find('div').get_text().split(' – ')
                job_company = company_location[0][1:]
                job_city = company_location[1].split(', ')[0]
                job_state = company_location[1].split(', ')[1]
                if job.find('span', class_='green small'):
                    job_salary = job.find('span', class_='green small').get_text()[1:]
                else:
                    job_salary = ''
                result_list.append((job_name, job_company, job_city, job_state, job_salary, job_url))

            return result_list         
        else:
            print('Location not available.')
              
    except:
        print('Fail to find jobs.')

# %%
result = get_job_list(place, keyword)

# %%
result
# Out:
# [('Android Engineer',
#   'eharmony',
#   'Los Angeles',
#   'CA',
#   '$105k-$163k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=318376&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_01cffcb5&cb=1543770373235&jobListingId=2960185184'),
#  ('Software Engineer',
#   'eharmony',
#   'Los Angeles',
#   'CA',
#   '$110k-$174k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=318374&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_69a5d9b5&cb=1543770373236&jobListingId=3035925492'),
#  ('Software Engineer, Backend',
#   'Snap Inc.',
#   'Los Angeles',
#   'CA',
#   '$131k-$208k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=439861&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_9021ca18&cb=1543770373237&jobListingId=2859118728'),
#  ('Software Engineer, Android',
#   'Snap Inc.',
#   'Los Angeles',
#   'CA',
#   '$131k-$208k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=439861&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_bf73e164&cb=1543770373238&jobListingId=3042005297'),
#  ('Software Engineer, iOS',
#   'Snap Inc.',
#   'Los Angeles',
#   'CA',
#   '$131k-$208k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=439861&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_ead52289&cb=1543770373239&jobListingId=3042005337'),
#  ('Software Developer',
#   'EcoSense Lighting',
#   'Los Angeles',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=297641&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_f06e34e3&cb=1543770373240&jobListingId=3018842531'),
#  ('Senior Android Engineer',
#   'Tinder',
#   'Los Angeles',
#   'CA',
#   '$131k-$202k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=433097&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&aa=1&ea=1&cs=1_d2e4a1df&cb=1543770373241&jobListingId=2998163793'),
#  ('Software Engineer',
#   'PDG Consulting',
#   'Los Angeles',
#   'CA',
#   '$70k-$115k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=303799&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_c91da440&cb=1543770373242&jobListingId=2993654072'),
#  ('Android Developer',
#   'Factual',
#   'Los Angeles',
#   'CA',
#   '$112k-$174k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=322198&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_41028185&cb=1543770373243&jobListingId=2909234457'),
#  ('Android Developer',
#   'Whisper',
#   'Venice',
#   'CA',
#   '$73k-$117k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=148364&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_cc5b08bf&cb=1543770373244&jobListingId=2941018053'),
#  ('Android Engineer',
#   'Grindr',
#   'Los Angeles',
#   'CA',
#   '$96k-$150k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=288529&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&aa=1&ea=1&cs=1_85fccb29&cb=1543770373245&jobListingId=2913400222'),
#  ('Senior Android Developer',
#   'Spokeo',
#   'Pasadena',
#   'CA',
#   '$115k-$178k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=441344&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_99a755b1&cb=1543770373246&jobListingId=2945204971'),
#  ('Android Developer',
#   'Walt Disney Company',
#   'Burbank',
#   'CA',
#   '$90k-$141k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=37049&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_31273582&cb=1543770373248&jobListingId=2885700923'),
#  ('Android Developer',
#   'LogicNext',
#   'Van Nuys',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=4120&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_a87271b7&cb=1543770373249&jobListingId=2299120824'),
#  ('Android Developer Intern',
#   'ePaisa',
#   'West Hollywood',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=4120&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_527123b6&cb=1543770373250&jobListingId=2429342643'),
#  ('Android Developer',
#   'Mobile programming',
#   'Los Angeles',
#   'CA',
#   '$49k-$79k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=372858&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_600fcc77&cb=1543770373251&jobListingId=3044403462'),
#  ('Android Developer',
#   'PlanetArt',
#   'Calabasas',
#   'CA',
#   '$88k-$138k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=389273&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_5962dca4&cb=1543770373253&jobListingId=3030577189'),
#  ('Android Developer',
#   'Cedars-Sinai',
#   'Los Angeles',
#   'CA',
#   '$81k-$128k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=133609&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_0af68f19&cb=1543770373254&jobListingId=3040829407'),
#  ('Android Developer',
#   'Sidecar Health, Inc',
#   'El Segundo',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=58033&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_7c04df8c&cb=1543770373255&jobListingId=2656818155'),
#  ('Android Developer',
#   'Lucky Day',
#   'Los Angeles',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=148364&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_79c103e7&cb=1543770373256&jobListingId=2960201011'),
#  ('Android Developer',
#   'Ace Technologies',
#   'Los Angeles',
#   'CA',
#   '$53k-$86k(Glassdoor Est.)',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=352789&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_726c543d&cb=1543770373257&jobListingId=3031233298'),
#  ('Android Developer',
#   'Ideatree',
#   'Los Angeles',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=66506&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_9b7e3909&cb=1543770373259&jobListingId=3024295027'),
#  ('Android Developer',
#   'Airfind',
#   'Santa Monica',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=301308&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_1d3f13e0&cb=1543770373260&jobListingId=2951853827'),
#  ('Android Developer',
#   'Ramy Infotech',
#   'Pasadena',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=4120&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_37d8f2a1&cb=1543770373261&jobListingId=3042524869'),
#  ('Android Developer',
#   'Tentek, Inc.',
#   'Culver City',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=85058&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_f77e9929&cb=1543770373262&jobListingId=3021766942'),
#  ('Android Developer',
#   'ePaisa',
#   'Los Angeles',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=4120&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_81f6f8d8&cb=1543770373263&jobListingId=2783285249'),
#  ('Android Developer',
#   'Robert Half Technology',
#   'Los Angeles',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=133516&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_f6b20426&cb=1543770373264&jobListingId=3003619589'),
#  ('Android Developer',
#   'Login Consulting Services',
#   'El Segundo',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=4120&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_eb231f8b&cb=1543770373265&jobListingId=2993343858'),
#  ('Android Developer',
#   'CyberCoders',
#   'Beverly Hills',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=129&ao=291820&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_aecc2db3&cb=1543770373266&jobListingId=3040601133'),
#  ('Android Developer',
#   'HIRECLOUT',
#   'Los Angeles',
#   'CA',
#   '',
#   'https://www.glassdoor.com/partner/jobListing.htm?pos=130&ao=9619&s=58&guid=000001676fe27a9e8d77d73f769c9244&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_4e2675fe&cb=1543770373267&jobListingId=2916109862')]
