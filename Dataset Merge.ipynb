# %%
import pandas as pd
import numpy as np

# %%
path='/Users/shmylm/Desktop/Project/'

# %%
LA=pd.read_csv(path+'business analyst-Los Angeles-job-results-desc.csv')

# %%
Houston=pd.read_csv(path+'business analyst-Houston-job-results-desc.csv')

# %%
result = pd.concat([LA, Houston],ignore_index=True)

# %%
result
# Out:
#                                                    Name  \
# 0                         Business Intelligence Analyst
# 1                         Business Intelligence Analyst
# 2                                      Business Analyst
# 3                                      Business Analyst
# 4                                      Business Analyst
# 5                                      Business Analyst
# 6                  Business Analyst (Contract Position)
# 7                                      Business Analyst
# 8                                      Business Analyst
# 9                                      Business Analyst
# 10                                     Business Analyst
# 11                                     Business Analyst
# 12                                     Business Analyst
# 13                                     Business Analyst
# 14                                     Business Analyst
# 15                                     Business Analyst
# ...
